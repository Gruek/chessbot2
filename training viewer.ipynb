# %%
from trainer import Trainer
t = Trainer()
# Out:
# D:\Program Files\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
t.train_vs_stockfish(debug=True, think_time=20, depth=6)
# Out:
# 0-1 68 0
# Epoch 1/1
# 68/68 [==============================] - 6s 87ms/step - loss: 2.3754 - activation_1_loss: 2.0000 - activation_2_loss: 0.3753 - activation_1_acc: 0.4118 - activation_2_acc: 0.7206
# Wins: 0 Draws: 0 Games: 1 Think Time: 20
# {'score': 0.3221625, 'visits': 0}
# total simulations: 818 depth: 6
# {'move': 'e2e4', 'visits': 773, 'score': 0.3300122618675232, 'weight': 0.03534689}
# {'move': 'g1f3', 'visits': 11, 'score': 0.4744703769683838, 'weight': 0.73052776}
# {'move': 'd2d4', 'visits': 10, 'score': 0.47875410318374634, 'weight': 0.2076424}
# Board('rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1')
# Board('rnbqkbnr/pppp1ppp/4p3/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2')
# {'score': 0.707228422164917, 'visits': 131}
# total simulations: 1110 depth: 6
# {'move': 'b1c3', 'visits': 630, 'score': 0.31995004415512085, 'weight': 0.0015343535}
# {'move': 'g1f3', 'visits': 334, 'score': 0.3758280873298645, 'weight': 0.05562866}
# {'move': 'd2d4', 'visits': 131, 'score': 0.43218493461608887, 'weight': 0.9358956}
# total simulations: 1383 depth: 6
# {'move': 'b1c3', 'visits': 865, 'score': 0.31995004415512085, 'weight': 0.0015343535}
# {'move': 'g1f3', 'visits': 334, 'score': 0.3758280873298645, 'weight': 0.05562866}
# {'move': 'd2d4', 'visits': 131, 'score': 0.43218493461608887, 'weight': 0.9358956}
# Board('rnbqkbnr/pppp1ppp/4p3/8/4P3/2N5/PPPP1PPP/R1BQKBNR b KQkq - 1 2')
# Board('rnbqkbnr/ppp2ppp/4p3/3p4/4P3/2N5/PPPP1PPP/R1BQKBNR w KQkq - 0 3')
# {'score': 0.6800499558448792, 'visits': 647}
# total simulations: 1021 depth: 6
# {'move': 'd2d4', 'visits': 977, 'score': 0.23105716705322266, 'weight': 0.5798991}
# {'move': 'e4d5', 'visits': 14, 'score': 0.43218493461608887, 'weight': 0.3949262}
# {'move': 'f1b5', 'visits': 7, 'score': 0.48323333263397217, 'weight': 0.00823176}
# Board('rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/2N5/PPP2PPP/R1BQKBNR b KQkq - 0 3')
# Board('rnbqkb1r/ppp2ppp/4pn2/3p4/3PP3/2N5/PPP2PPP/R1BQKBNR w KQkq - 1 4')
# {'score': 0.7689428329467773, 'visits': 493}
# total simulations: 1178 depth: 6
# {'move': 'e4e5', 'visits': 1007, 'score': 0.14187031984329224, 'weight': 0.3494643}
# {'move': 'c1g5', 'visits': 75, 'score': 0.34982824325561523, 'weight': 0.1282169}
# {'move': 'f1d3', 'visits': 22, 'score': 0.4572809338569641, 'weight': 0.06720569}
# total simulations: 1387 depth: 6
# {'move': 'e4e5', 'visits': 1191, 'score': 0.32551389932632446, 'weight': 0.3494643}
# {'move': 'c1g5', 'visits': 75, 'score': 0.34982824325561523, 'weight': 0.1282169}
# {'move': 'f1d3', 'visits': 22, 'score': 0.4572809338569641, 'weight': 0.06720569}
# Board('rnbqkb1r/ppp2ppp/4pn2/3pP3/3P4/2N5/PPP2PPP/R1BQKBNR b KQkq - 0 4')
# Board('rnbqkb1r/pppn1ppp/4p3/3pP3/3P4/2N5/PPP2PPP/R1BQKBNR w KQkq - 1 5')
# {'score': 0.6744861006736755, 'visits': 288}
# total simulations: 674 depth: 6
# {'move': 'c3d5', 'visits': 274, 'score': 0.1742498278617859, 'weight': 0.0010453204}
# {'move': 'g1f3', 'visits': 55, 'score': 0.2121049165725708, 'weight': 0.31316054}
# {'move': 'g1h3', 'visits': 18, 'score': 0.3776782155036926, 'weight': 0.004117222}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-21d0d836166e> in <module>()
# ----> 1 t.train_vs_stockfish(debug=True, think_time=20, depth=6)
#
# D:\Python\rl_chess\trainer.py in train_vs_stockfish(self, debug, think_time, depth)
#      47         games = 0
#      48         while True:
# ---> 49             board, win = self.play_vs_stockfish(fish, think_time=think_time, depth=depth, debug=debug)
#      50             if win == 1:
#      51                 wins += 1
#
# D:\Python\rl_chess\trainer.py in play_vs_stockfish(self, fish, think_time, depth, debug)
#      26                     if last_score > 0.95 or last_score < 0.05:
#      27                         ttt = think_time / 3
# ---> 28                 move = self.chbot.best_move(board, time_limit=ttt, depth=depth, debug=debug)
#      29                 last_score = move['score']
#      30                 board.push_uci(move['move'])
#
# D:\Python\rl_chess\bot.py in best_move(self, board, depth, time_limit, debug, eval_freq)
#      30             print(self.game.root())
#      31
# ---> 32         best_move = self.mcts(depth, time_limit, debug, eval_freq)
#      33         return best_move
#      34
#
# D:\Python\rl_chess\bot.py in mcts(self, depth, time_limit, debug, eval_freq)
#      52
#      53             # simulate game
# ---> 54             self.simulate_game(depth)
#      55
#      56             # out of time
#
# D:\Python\rl_chess\bot.py in simulate_game(self, depth)
#      90         self.game.push(sample_move)
#      91
# ---> 92         self.simulate_game(depth-1)
#      93         sample_node = self.game.node()
#      94         sample_score = 1 - sample_node.score
#
# D:\Python\rl_chess\bot.py in simulate_game(self, depth)
#      90         self.game.push(sample_move)
#      91
# ---> 92         self.simulate_game(depth-1)
#      93         sample_node = self.game.node()
#      94         sample_score = 1 - sample_node.score
#
# D:\Python\rl_chess\bot.py in simulate_game(self, depth)
#      90         self.game.push(sample_move)
#      91
# ---> 92         self.simulate_game(depth-1)
#      93         sample_node = self.game.node()
#      94         sample_score = 1 - sample_node.score
#
# D:\Python\rl_chess\bot.py in simulate_game(self, depth)
#      90         self.game.push(sample_move)
#      91
# ---> 92         self.simulate_game(depth-1)
#      93         sample_node = self.game.node()
#      94         sample_score = 1 - sample_node.score
#
# D:\Python\rl_chess\bot.py in simulate_game(self, depth)
#      88         sample_move = self.choose_next_move(node)
#      89         self.meta_data['choose_move_time'] += time.time() - t1
# ---> 90         self.game.push(sample_move)
#      91
#      92         self.simulate_game(depth-1)
#
# D:\Python\rl_chess\node.py in push(self, move)
#      40             self.meta_data['push_time'] += time.time() - t1
#      41             expand_t = time.time()
# ---> 42             next_node = self.expand()
#      43             self.meta_data['expand_time'] += time.time() - expand_t
#      44             t1 = time.time()
#
# D:\Python\rl_chess\node.py in expand(self)
#     129         # run model
#     130         t1 = time.time()
# --> 131         policies, values = self.model.predict([board_inputs, castling_inputs])
#     132         self.meta_data['infer_time'] += time.time() - t1
#     133         policy, value = policies[0], values[0][0]
#
# D:\Program Files\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# D:\Program Files\Anaconda3\lib\site-packages\keras\engine\training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1328                     ins_batch[i] = ins_batch[i].toarray()
#    1329
# -> 1330                 batch_outs = f(ins_batch)
#    1331                 if not isinstance(batch_outs, list):
#    1332                     batch_outs = [batch_outs]
#
# D:\Program Files\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# D:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# D:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# D:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# D:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# D:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
t.train_vs_self(debug=True)
